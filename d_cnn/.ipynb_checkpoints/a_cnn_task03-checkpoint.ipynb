# %% [markdown]
# ### 표정 분류
#
# https://drive.google.com/file/d/1lpwQNwijBfaSr8knSNHKWu5KUmzYWU9d/view?usp=drive_link

# %% [markdown]
# #### train

# %%
from glob import glob
import os

# 이미지가 저장되어 있는 경로 지정
root = './datasets/face/original/'

# 해당 경로를 통해 이미지 폴더를 찾아옴
directories = glob(os.path.join(root, '*'))

# %%
directories
# Out:
# ['./datasets/face/original\\angry',
#  './datasets/face/original\\disgust',
#  './datasets/face/original\\fear',
#  './datasets/face/original\\happy',
#  './datasets/face/original\\neutral',
#  './datasets/face/original\\sad',
#  './datasets/face/original\\surprise']

# %%
# 폴더 이름 저장할 초기 list 생성
directory_names = []

for directory in directories:
    # 디렉토리의 이름을 찾아와서 list에 저장
    directory_names.append(directory[directory.rindex('\\') + 1:])

print(directory_names)
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
# 이미지 별 폴더 안 이미지들의 파일명 변경
for name in directory_names:
    for i, file_name in enumerate(os.listdir(os.path.join(root, name))):
        # 이전 파일의 전체 경로
        old_file = os.path.join(root + name + '/', file_name)
        # 신규 파일 전체 경로 작성
        new_file = os.path.join(root + name + '/', name + str(i + 1) + '.png')

        # 이전 파일의 이름을 신규 파일로 변경
        os.rename(old_file, new_file)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 이미지의 픽셀 값을 0에서 255 사이에서 0에서 1 사이의 값으로 조정
image_data_generator = ImageDataGenerator(rescale=1./255)

# 디렉토리에서 이미지를 가져와 배치로 변환
generator = image_data_generator.flow_from_directory(root, target_size=(150, 150), batch_size=32, class_mode='categorical')

print(generator.class_indices)
# Out:
# Found 28709 images belonging to 7 classes.
# {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}

# %%
generator.filepaths
# Out:
# ['./datasets/face/original/angry\\angry1.png',
#  './datasets/face/original/angry\\angry10.png',
#  './datasets/face/original/angry\\angry100.png',
#  './datasets/face/original/angry\\angry1000.png',
#  './datasets/face/original/angry\\angry1001.png',
#  './datasets/face/original/angry\\angry1002.png',
#  './datasets/face/original/angry\\angry1003.png',
#  './datasets/face/original/angry\\angry1004.png',
#  './datasets/face/original/angry\\angry1005.png',
#  './datasets/face/original/angry\\angry1006.png',
#  './datasets/face/original/angry\\angry1007.png',
#  './datasets/face/original/angry\\angry1008.png',
#  './datasets/face/original/angry\\angry1009.png',
#  './datasets/face/original/angry\\angry101.png',
#  './datasets/face/original/angry\\angry1010.png',
#  './datasets/face/original/angry\\angry1011.png',
#  './datasets/face/original/angry\\angry1012.png',
#  './datasets/face/original/angry\\angry1013.png',
#  './datasets/face/original/angry\\angry1014.png',
#  './datasets/face/original/angry\\angry1015.png',
#  './datasets/face/original/angry\\angry1016.png',
#  './datasets/face/original/angry\\angry1017.png',
#  './datasets/face/original/angry\\angry1018.png',
#  './datasets/face/original/angry\\angry1019.png',
#  './datasets/face/original/angry\\angry102.png',
#  './datasets/face/original/angry\\angry1020.png',
#  './datasets/face/original/angry\\angry1021.png',
#  './datasets/face/original/angry\\angry1022.png',
#  './datasets/face/original/angry\\angry1023.png',
#  './datasets/face/original/angry\\angry1024.png',
#  './datasets/face/original/angry\\angry1025.png',
#  './datasets/face/original/angry\\angry1026.png',
#  './datasets/face/original/angry\\angry1027.png',
#  './datasets/face/original/angry\\angry1028.png',
#  './datasets/face/original/angry\\angry1029.png',
#  './datasets/face/original/angry\\angry103.png',
#  './datasets/face/original/angry\\angry1030.png',
#  './datasets/face/original/angry\\angry1031.png',
#  './datasets/face/original/angry\\angry1032.png',
#  './datasets/face/original/angry\\angry1033.png',
#  './datasets/face/original/angry\\angry1034.png',
#  './datasets/face/original/angry\\angry1035.png',
#  './datasets/face/original/angry\\angry1036.png',
#  './datasets/face/original/angry\\angry1037.png',
#  './datasets/face/original/angry\\angry1038.png',
#  './datasets/face/original/angry\\angry1039.png',
#  './datasets/face/original/angry\\angry104.png',
#  './datasets/face/original/angry\\angry1040.png',
#  './datasets/face/original/angry\\angry1041.png',
#  './datasets/face/original/angry\\angry1042.png',
#  './datasets/face/original/angry\\angry1043.png',
#  './datasets/face/original/angry\\angry1044.png',
#  './datasets/face/original/angry\\angry1045.png',
#  './datasets/face/original/angry\\angry1046.png',
#  './datasets/face/original/angry\\angry1047.png',
#  './datasets/face/original/angry\\angry1048.png',
#  './datasets/face/original/angry\\angry1049.png',
#  './datasets/face/original/angry\\angry105.png',
#  './datasets/face/original/angry\\angry1050.png',
#  './datasets/face/original/angry\\angry1051.png',
#  './datasets/face/original/angry\\angry1052.png',
#  './datasets/face/original/angry\\angry1053.png',
#  './datasets/face/original/angry\\angry1054.png',
#  './datasets/face/original/angry\\angry1055.png',
#  './datasets/face/original/angry\\angry1056.png',
#  './datasets/face/original/angry\\angry1057.png',
#  './datasets/face/original/angry\\angry1058.png',
#  './datasets/face/original/angry\\angry1059.png',
#  './datasets/face/original/angry\\angry106.png',
#  './datasets/face/original/angry\\angry1060.png',
#  './datasets/face/original/angry\\angry1061.png',
#  './datasets/face/original/angry\\angry1062.png',
#  './datasets/face/original/angry\\angry1063.png',
#  './datasets/face/original/angry\\angry1064.png',
#  './datasets/face/original/angry\\angry1065.png',
#  './datasets/face/original/angry\\angry1066.png',
#  './datasets/face/original/angry\\angry1067.png',
#  './datasets/face/original/angry\\angry1068.png',
#  './datasets/face/original/angry\\angry1069.png',
#  './datasets/face/original/angry\\angry107.png',
#  './datasets/face/original/angry\\angry1070.png',
#  './datasets/face/original/angry\\angry1071.png',
#  './datasets/face/original/angry\\angry1072.png',
#  './datasets/face/original/angry\\angry1073.png',
#  './datasets/face/original/angry\\angry1074.png',
#  './datasets/face/original/angry\\angry1075.png',
#  './datasets/face/original/angry\\angry1076.png',
#  './datasets/face/original/angry\\angry1077.png',
#  './datasets/face/original/angry\\angry1078.png',
#  './datasets/face/original/angry\\angry1079.png',
#  './datasets/face/original/angry\\angry108.png',
#  './datasets/face/original/angry\\angry1080.png',
#  './datasets/face/original/angry\\angry1081.png',
#  './datasets/face/original/angry\\angry1082.png',
#  './datasets/face/original/angry\\angry1083.png',
#  './datasets/face/original/angry\\angry1084.png',
#  './datasets/face/original/angry\\angry1085.png',
#  './datasets/face/original/angry\\angry1086.png',
#  './datasets/face/original/angry\\angry1087.png',
#  './datasets/face/original/angry\\angry1088.png',
#  './datasets/face/original/angry\\angry1089.png',
#  './datasets/face/original/angry\\angry109.png',
#  './datasets/face/original/angry\\angry1090.png',
#  './datasets/face/original/angry\\angry1091.png',
#  './datasets/face/original/angry\\angry1092.png',
#  './datasets/face/original/angry\\angry1093.png',
#  './datasets/face/original/angry\\angry1094.png',
#  './datasets/face/original/angry\\angry1095.png',
#  './datasets/face/original/angry\\angry1096.png',
#  './datasets/face/original/angry\\angry1097.png',
#  './datasets/face/original/angry\\angry1098.png',
#  './datasets/face/original/angry\\angry1099.png',
#  './datasets/face/original/angry\\angry11.png',
#  './datasets/face/original/angry\\angry110.png',
#  './datasets/face/original/angry\\angry1100.png',
#  './datasets/face/original/angry\\angry1101.png',
#  './datasets/face/original/angry\\angry1102.png',
#  './datasets/face/original/angry\\angry1103.png',
#  './datasets/face/original/angry\\angry1104.png',
#  './datasets/face/original/angry\\angry1105.png',
#  './datasets/face/original/angry\\angry1106.png',
#  './datasets/face/original/angry\\angry1107.png',
#  './datasets/face/original/angry\\angry1108.png',
#  './datasets/face/original/angry\\angry1109.png',
#  './datasets/face/original/angry\\angry111.png',
#  './datasets/face/original/angry\\angry1110.png',
#  './datasets/face/original/angry\\angry1111.png',
#  './datasets/face/original/angry\\angry1112.png',
#  './datasets/face/original/angry\\angry1113.png',
#  './datasets/face/original/angry\\angry1114.png',
#  './datasets/face/original/angry\\angry1115.png',
#  './datasets/face/original/angry\\angry1116.png',
#  './datasets/face/original/angry\\angry1117.png',
#  './datasets/face/original/angry\\angry1118.png',
#  './datasets/face/original/angry\\angry1119.png',
#  './datasets/face/original/angry\\angry112.png',
#  './datasets/face/original/angry\\angry1120.png',
#  './datasets/face/original/angry\\angry1121.png',
#  './datasets/face/original/angry\\angry1122.png',
#  './datasets/face/original/angry\\angry1123.png',
#  './datasets/face/original/angry\\angry1124.png',
#  './datasets/face/original/angry\\angry1125.png',
#  './datasets/face/original/angry\\angry1126.png',
#  './datasets/face/original/angry\\angry1127.png',
#  './datasets/face/original/angry\\angry1128.png',
#  './datasets/face/original/angry\\angry1129.png',
#  './datasets/face/original/angry\\angry113.png',
#  './datasets/face/original/angry\\angry1130.png',
#  './datasets/face/original/angry\\angry1131.png',
#  './datasets/face/original/angry\\angry1132.png',
#  './datasets/face/original/angry\\angry1133.png',
#  './datasets/face/original/angry\\angry1134.png',
#  './datasets/face/original/angry\\angry1135.png',
#  './datasets/face/original/angry\\angry1136.png',
#  './datasets/face/original/angry\\angry1137.png',
#  './datasets/face/original/angry\\angry1138.png',
#  './datasets/face/original/angry\\angry1139.png',
#  './datasets/face/original/angry\\angry114.png',
#  './datasets/face/original/angry\\angry1140.png',
#  './datasets/face/original/angry\\angry1141.png',
#  './datasets/face/original/angry\\angry1142.png',
#  './datasets/face/original/angry\\angry1143.png',
#  './datasets/face/original/angry\\angry1144.png',
#  './datasets/face/original/angry\\angry1145.png',
#  './datasets/face/original/angry\\angry1146.png',
#  './datasets/face/original/angry\\angry1147.png',
#  './datasets/face/original/angry\\angry1148.png',
#  './datasets/face/original/angry\\angry1149.png',
#  './datasets/face/original/angry\\angry115.png',
#  './datasets/face/original/angry\\angry1150.png',
#  './datasets/face/original/angry\\angry1151.png',
#  './datasets/face/original/angry\\angry1152.png',
#  './datasets/face/original/angry\\angry1153.png',
#  './datasets/face/original/angry\\angry1154.png',
#  './datasets/face/original/angry\\angry1155.png',
#  './datasets/face/original/angry\\angry1156.png',
#  './datasets/face/original/angry\\angry1157.png',
#  './datasets/face/original/angry\\angry1158.png',
#  './datasets/face/original/angry\\angry1159.png',
#  './datasets/face/original/angry\\angry116.png',
#  './datasets/face/original/angry\\angry1160.png',
#  './datasets/face/original/angry\\angry1161.png',
#  './datasets/face/original/angry\\angry1162.png',
#  './datasets/face/original/angry\\angry1163.png',
#  './datasets/face/original/angry\\angry1164.png',
#  './datasets/face/original/angry\\angry1165.png',
#  './datasets/face/original/angry\\angry1166.png',
#  './datasets/face/original/angry\\angry1167.png',
#  './datasets/face/original/angry\\angry1168.png',
#  './datasets/face/original/angry\\angry1169.png',
#  './datasets/face/original/angry\\angry117.png',
#  './datasets/face/original/angry\\angry1170.png',
#  './datasets/face/original/angry\\angry1171.png',
#  './datasets/face/original/angry\\angry1172.png',
#  './datasets/face/original/angry\\angry1173.png',
#  './datasets/face/original/angry\\angry1174.png',
#  './datasets/face/original/angry\\angry1175.png',
#  './datasets/face/original/angry\\angry1176.png',
#  './datasets/face/original/angry\\angry1177.png',
#  './datasets/face/original/angry\\angry1178.png',
#  './datasets/face/original/angry\\angry1179.png',
#  './datasets/face/original/angry\\angry118.png',
#  './datasets/face/original/angry\\angry1180.png',
#  './datasets/face/original/angry\\angry1181.png',
#  './datasets/face/original/angry\\angry1182.png',
#  './datasets/face/original/angry\\angry1183.png',
#  './datasets/face/original/angry\\angry1184.png',
#  './datasets/face/original/angry\\angry1185.png',
#  './datasets/face/original/angry\\angry1186.png',
#  './datasets/face/original/angry\\angry1187.png',
#  './datasets/face/original/angry\\angry1188.png',
#  './datasets/face/original/angry\\angry1189.png',
#  './datasets/face/original/angry\\angry119.png',
#  './datasets/face/original/angry\\angry1190.png',
#  './datasets/face/original/angry\\angry1191.png',
#  './datasets/face/original/angry\\angry1192.png',
#  './datasets/face/original/angry\\angry1193.png',
#  './datasets/face/original/angry\\angry1194.png',
#  './datasets/face/original/angry\\angry1195.png',
#  './datasets/face/original/angry\\angry1196.png',
#  './datasets/face/original/angry\\angry1197.png',
#  './datasets/face/original/angry\\angry1198.png',
#  './datasets/face/original/angry\\angry1199.png',
#  './datasets/face/original/angry\\angry12.png',
#  './datasets/face/original/angry\\angry120.png',
#  './datasets/face/original/angry\\angry1200.png',
#  './datasets/face/original/angry\\angry1201.png',
#  './datasets/face/original/angry\\angry1202.png',
#  './datasets/face/original/angry\\angry1203.png',
#  './datasets/face/original/angry\\angry1204.png',
#  './datasets/face/original/angry\\angry1205.png',
#  './datasets/face/original/angry\\angry1206.png',
#  './datasets/face/original/angry\\angry1207.png',
#  './datasets/face/original/angry\\angry1208.png',
#  './datasets/face/original/angry\\angry1209.png',
#  './datasets/face/original/angry\\angry121.png',
#  './datasets/face/original/angry\\angry1210.png',
#  './datasets/face/original/angry\\angry1211.png',
#  './datasets/face/original/angry\\angry1212.png',
#  './datasets/face/original/angry\\angry1213.png',
#  './datasets/face/original/angry\\angry1214.png',
#  './datasets/face/original/angry\\angry1215.png',
#  './datasets/face/original/angry\\angry1216.png',
#  './datasets/face/original/angry\\angry1217.png',
#  './datasets/face/original/angry\\angry1218.png',
#  './datasets/face/original/angry\\angry1219.png',
#  './datasets/face/original/angry\\angry122.png',
#  './datasets/face/original/angry\\angry1220.png',
#  './datasets/face/original/angry\\angry1221.png',
#  './datasets/face/original/angry\\angry1222.png',
#  './datasets/face/original/angry\\angry1223.png',
#  './datasets/face/original/angry\\angry1224.png',
#  './datasets/face/original/angry\\angry1225.png',
#  './datasets/face/original/angry\\angry1226.png',
#  './datasets/face/original/angry\\angry1227.png',
#  './datasets/face/original/angry\\angry1228.png',
#  './datasets/face/original/angry\\angry1229.png',
#  './datasets/face/original/angry\\angry123.png',
#  './datasets/face/original/angry\\angry1230.png',
#  './datasets/face/original/angry\\angry1231.png',
#  './datasets/face/original/angry\\angry1232.png',
#  './datasets/face/original/angry\\angry1233.png',
#  './datasets/face/original/angry\\angry1234.png',
#  './datasets/face/original/angry\\angry1235.png',
#  './datasets/face/original/angry\\angry1236.png',
#  './datasets/face/original/angry\\angry1237.png',
#  './datasets/face/original/angry\\angry1238.png',
#  './datasets/face/original/angry\\angry1239.png',
#  './datasets/face/original/angry\\angry124.png',
#  './datasets/face/original/angry\\angry1240.png',
#  './datasets/face/original/angry\\angry1241.png',
#  './datasets/face/original/angry\\angry1242.png',
#  './datasets/face/original/angry\\angry1243.png',
#  './datasets/face/original/angry\\angry1244.png',
#  './datasets/face/original/angry\\angry1245.png',
#  './datasets/face/original/angry\\angry1246.png',
#  './datasets/face/original/angry\\angry1247.png',
#  './datasets/face/original/angry\\angry1248.png',
#  './datasets/face/original/angry\\angry1249.png',
#  './datasets/face/original/angry\\angry125.png',
#  './datasets/face/original/angry\\angry1250.png',
#  './datasets/face/original/angry\\angry1251.png',
#  './datasets/face/original/angry\\angry1252.png',
#  './datasets/face/original/angry\\angry1253.png',
#  './datasets/face/original/angry\\angry1254.png',
#  './datasets/face/original/angry\\angry1255.png',
#  './datasets/face/original/angry\\angry1256.png',
#  './datasets/face/original/angry\\angry1257.png',
#  './datasets/face/original/angry\\angry1258.png',
#  './datasets/face/original/angry\\angry1259.png',
#  './datasets/face/original/angry\\angry126.png',
#  './datasets/face/original/angry\\angry1260.png',
#  './datasets/face/original/angry\\angry1261.png',
#  './datasets/face/original/angry\\angry1262.png',
#  './datasets/face/original/angry\\angry1263.png',
#  './datasets/face/original/angry\\angry1264.png',
#  './datasets/face/original/angry\\angry1265.png',
#  './datasets/face/original/angry\\angry1266.png',
#  './datasets/face/original/angry\\angry1267.png',
#  './datasets/face/original/angry\\angry1268.png',
#  './datasets/face/original/angry\\angry1269.png',
#  './datasets/face/original/angry\\angry127.png',
#  './datasets/face/original/angry\\angry1270.png',
#  './datasets/face/original/angry\\angry1271.png',
#  './datasets/face/original/angry\\angry1272.png',
#  './datasets/face/original/angry\\angry1273.png',
#  './datasets/face/original/angry\\angry1274.png',
#  './datasets/face/original/angry\\angry1275.png',
#  './datasets/face/original/angry\\angry1276.png',
#  './datasets/face/original/angry\\angry1277.png',
#  './datasets/face/original/angry\\angry1278.png',
#  './datasets/face/original/angry\\angry1279.png',
#  './datasets/face/original/angry\\angry128.png',
#  './datasets/face/original/angry\\angry1280.png',
#  './datasets/face/original/angry\\angry1281.png',
#  './datasets/face/original/angry\\angry1282.png',
#  './datasets/face/original/angry\\angry1283.png',
#  './datasets/face/original/angry\\angry1284.png',
#  './datasets/face/original/angry\\angry1285.png',
#  './datasets/face/original/angry\\angry1286.png',
#  './datasets/face/original/angry\\angry1287.png',
#  './datasets/face/original/angry\\angry1288.png',
#  './datasets/face/original/angry\\angry1289.png',
#  './datasets/face/original/angry\\angry129.png',
#  './datasets/face/original/angry\\angry1290.png',
#  './datasets/face/original/angry\\angry1291.png',
#  './datasets/face/original/angry\\angry1292.png',
#  './datasets/face/original/angry\\angry1293.png',
#  './datasets/face/original/angry\\angry1294.png',
#  './datasets/face/original/angry\\angry1295.png',
#  './datasets/face/original/angry\\angry1296.png',
#  './datasets/face/original/angry\\angry1297.png',
#  './datasets/face/original/angry\\angry1298.png',
#  './datasets/face/original/angry\\angry1299.png',
#  './datasets/face/original/angry\\angry13.png',
#  './datasets/face/original/angry\\angry130.png',
#  './datasets/face/original/angry\\angry1300.png',
#  './datasets/face/original/angry\\angry1301.png',
#  './datasets/face/original/angry\\angry1302.png',
#  './datasets/face/original/angry\\angry1303.png',
#  './datasets/face/original/angry\\angry1304.png',
#  './datasets/face/original/angry\\angry1305.png',
#  './datasets/face/original/angry\\angry1306.png',
#  './datasets/face/original/angry\\angry1307.png',
#  './datasets/face/original/angry\\angry1308.png',
#  './datasets/face/original/angry\\angry1309.png',
#  './datasets/face/original/angry\\angry131.png',
#  './datasets/face/original/angry\\angry1310.png',
#  './datasets/face/original/angry\\angry1311.png',
#  './datasets/face/original/angry\\angry1312.png',
#  './datasets/face/original/angry\\angry1313.png',
#  './datasets/face/original/angry\\angry1314.png',
#  './datasets/face/original/angry\\angry1315.png',
#  './datasets/face/original/angry\\angry1316.png',
#  './datasets/face/original/angry\\angry1317.png',
#  './datasets/face/original/angry\\angry1318.png',
#  './datasets/face/original/angry\\angry1319.png',
#  './datasets/face/original/angry\\angry132.png',
#  './datasets/face/original/angry\\angry1320.png',
#  './datasets/face/original/angry\\angry1321.png',
#  './datasets/face/original/angry\\angry1322.png',
#  './datasets/face/original/angry\\angry1323.png',
#  './datasets/face/original/angry\\angry1324.png',
#  './datasets/face/original/angry\\angry1325.png',
#  './datasets/face/original/angry\\angry1326.png',
#  './datasets/face/original/angry\\angry1327.png',
#  './datasets/face/original/angry\\angry1328.png',
#  './datasets/face/original/angry\\angry1329.png',
#  './datasets/face/original/angry\\angry133.png',
#  './datasets/face/original/angry\\angry1330.png',
#  './datasets/face/original/angry\\angry1331.png',
#  './datasets/face/original/angry\\angry1332.png',
#  './datasets/face/original/angry\\angry1333.png',
#  './datasets/face/original/angry\\angry1334.png',
#  './datasets/face/original/angry\\angry1335.png',
#  './datasets/face/original/angry\\angry1336.png',
#  './datasets/face/original/angry\\angry1337.png',
#  './datasets/face/original/angry\\angry1338.png',
#  './datasets/face/original/angry\\angry1339.png',
#  './datasets/face/original/angry\\angry134.png',
#  './datasets/face/original/angry\\angry1340.png',
#  './datasets/face/original/angry\\angry1341.png',
#  './datasets/face/original/angry\\angry1342.png',
#  './datasets/face/original/angry\\angry1343.png',
#  './datasets/face/original/angry\\angry1344.png',
#  './datasets/face/original/angry\\angry1345.png',
#  './datasets/face/original/angry\\angry1346.png',
#  './datasets/face/original/angry\\angry1347.png',
#  './datasets/face/original/angry\\angry1348.png',
#  './datasets/face/original/angry\\angry1349.png',
#  './datasets/face/original/angry\\angry135.png',
#  './datasets/face/original/angry\\angry1350.png',
#  './datasets/face/original/angry\\angry1351.png',
#  './datasets/face/original/angry\\angry1352.png',
#  './datasets/face/original/angry\\angry1353.png',
#  './datasets/face/original/angry\\angry1354.png',
#  './datasets/face/original/angry\\angry1355.png',
#  './datasets/face/original/angry\\angry1356.png',
#  './datasets/face/original/angry\\angry1357.png',
#  './datasets/face/original/angry\\angry1358.png',
#  './datasets/face/original/angry\\angry1359.png',
#  './datasets/face/original/angry\\angry136.png',
#  './datasets/face/original/angry\\angry1360.png',
#  './datasets/face/original/angry\\angry1361.png',
#  './datasets/face/original/angry\\angry1362.png',
#  './datasets/face/original/angry\\angry1363.png',
#  './datasets/face/original/angry\\angry1364.png',
#  './datasets/face/original/angry\\angry1365.png',
#  './datasets/face/original/angry\\angry1366.png',
#  './datasets/face/original/angry\\angry1367.png',
#  './datasets/face/original/angry\\angry1368.png',
#  './datasets/face/original/angry\\angry1369.png',
#  './datasets/face/original/angry\\angry137.png',
#  './datasets/face/original/angry\\angry1370.png',
#  './datasets/face/original/angry\\angry1371.png',
#  './datasets/face/original/angry\\angry1372.png',
#  './datasets/face/original/angry\\angry1373.png',
#  './datasets/face/original/angry\\angry1374.png',
#  './datasets/face/original/angry\\angry1375.png',
#  './datasets/face/original/angry\\angry1376.png',
#  './datasets/face/original/angry\\angry1377.png',
#  './datasets/face/original/angry\\angry1378.png',
#  './datasets/face/original/angry\\angry1379.png',
#  './datasets/face/original/angry\\angry138.png',
#  './datasets/face/original/angry\\angry1380.png',
#  './datasets/face/original/angry\\angry1381.png',
#  './datasets/face/original/angry\\angry1382.png',
#  './datasets/face/original/angry\\angry1383.png',
#  './datasets/face/original/angry\\angry1384.png',
#  './datasets/face/original/angry\\angry1385.png',
#  './datasets/face/original/angry\\angry1386.png',
#  './datasets/face/original/angry\\angry1387.png',
#  './datasets/face/original/angry\\angry1388.png',
#  './datasets/face/original/angry\\angry1389.png',
#  './datasets/face/original/angry\\angry139.png',
#  './datasets/face/original/angry\\angry1390.png',
#  './datasets/face/original/angry\\angry1391.png',
#  './datasets/face/original/angry\\angry1392.png',
#  './datasets/face/original/angry\\angry1393.png',
#  './datasets/face/original/angry\\angry1394.png',
#  './datasets/face/original/angry\\angry1395.png',
#  './datasets/face/original/angry\\angry1396.png',
#  './datasets/face/original/angry\\angry1397.png',
#  './datasets/face/original/angry\\angry1398.png',
#  './datasets/face/original/angry\\angry1399.png',
#  './datasets/face/original/angry\\angry14.png',
#  './datasets/face/original/angry\\angry140.png',
#  './datasets/face/original/angry\\angry1400.png',
#  './datasets/face/original/angry\\angry1401.png',
#  './datasets/face/original/angry\\angry1402.png',
#  './datasets/face/original/angry\\angry1403.png',
#  './datasets/face/original/angry\\angry1404.png',
#  './datasets/face/original/angry\\angry1405.png',
#  './datasets/face/original/angry\\angry1406.png',
#  './datasets/face/original/angry\\angry1407.png',
#  './datasets/face/original/angry\\angry1408.png',
#  './datasets/face/original/angry\\angry1409.png',
#  './datasets/face/original/angry\\angry141.png',
#  './datasets/face/original/angry\\angry1410.png',
#  './datasets/face/original/angry\\angry1411.png',
#  './datasets/face/original/angry\\angry1412.png',
#  './datasets/face/original/angry\\angry1413.png',
#  './datasets/face/original/angry\\angry1414.png',
#  './datasets/face/original/angry\\angry1415.png',
#  './datasets/face/original/angry\\angry1416.png',
#  './datasets/face/original/angry\\angry1417.png',
#  './datasets/face/original/angry\\angry1418.png',
#  './datasets/face/original/angry\\angry1419.png',
#  './datasets/face/original/angry\\angry142.png',
#  './datasets/face/original/angry\\angry1420.png',
#  './datasets/face/original/angry\\angry1421.png',
#  './datasets/face/original/angry\\angry1422.png',
#  './datasets/face/original/angry\\angry1423.png',
#  './datasets/face/original/angry\\angry1424.png',
#  './datasets/face/original/angry\\angry1425.png',
#  './datasets/face/original/angry\\angry1426.png',
#  './datasets/face/original/angry\\angry1427.png',
#  './datasets/face/original/angry\\angry1428.png',
#  './datasets/face/original/angry\\angry1429.png',
#  './datasets/face/original/angry\\angry143.png',
#  './datasets/face/original/angry\\angry1430.png',
#  './datasets/face/original/angry\\angry1431.png',
#  './datasets/face/original/angry\\angry1432.png',
#  './datasets/face/original/angry\\angry1433.png',
#  './datasets/face/original/angry\\angry1434.png',
#  './datasets/face/original/angry\\angry1435.png',
#  './datasets/face/original/angry\\angry1436.png',
#  './datasets/face/original/angry\\angry1437.png',
#  './datasets/face/original/angry\\angry1438.png',
#  './datasets/face/original/angry\\angry1439.png',
#  './datasets/face/original/angry\\angry144.png',
#  './datasets/face/original/angry\\angry1440.png',
#  './datasets/face/original/angry\\angry1441.png',
#  './datasets/face/original/angry\\angry1442.png',
#  './datasets/face/original/angry\\angry1443.png',
#  './datasets/face/original/angry\\angry1444.png',
#  './datasets/face/original/angry\\angry1445.png',
#  './datasets/face/original/angry\\angry1446.png',
#  './datasets/face/original/angry\\angry1447.png',
#  './datasets/face/original/angry\\angry1448.png',
#  './datasets/face/original/angry\\angry1449.png',
#  './datasets/face/original/angry\\angry145.png',
#  './datasets/face/original/angry\\angry1450.png',
#  './datasets/face/original/angry\\angry1451.png',
#  './datasets/face/original/angry\\angry1452.png',
#  './datasets/face/original/angry\\angry1453.png',
#  './datasets/face/original/angry\\angry1454.png',
#  './datasets/face/original/angry\\angry1455.png',
#  './datasets/face/original/angry\\angry1456.png',
#  './datasets/face/original/angry\\angry1457.png',
#  './datasets/face/original/angry\\angry1458.png',
#  './datasets/face/original/angry\\angry1459.png',
#  './datasets/face/original/angry\\angry146.png',
#  './datasets/face/original/angry\\angry1460.png',
#  './datasets/face/original/angry\\angry1461.png',
#  './datasets/face/original/angry\\angry1462.png',
#  './datasets/face/original/angry\\angry1463.png',
#  './datasets/face/original/angry\\angry1464.png',
#  './datasets/face/original/angry\\angry1465.png',
#  './datasets/face/original/angry\\angry1466.png',
#  './datasets/face/original/angry\\angry1467.png',
#  './datasets/face/original/angry\\angry1468.png',
#  './datasets/face/original/angry\\angry1469.png',
#  './datasets/face/original/angry\\angry147.png',
#  './datasets/face/original/angry\\angry1470.png',
#  './datasets/face/original/angry\\angry1471.png',
#  './datasets/face/original/angry\\angry1472.png',
#  './datasets/face/original/angry\\angry1473.png',
#  './datasets/face/original/angry\\angry1474.png',
#  './datasets/face/original/angry\\angry1475.png',
#  './datasets/face/original/angry\\angry1476.png',
#  './datasets/face/original/angry\\angry1477.png',
#  './datasets/face/original/angry\\angry1478.png',
#  './datasets/face/original/angry\\angry1479.png',
#  './datasets/face/original/angry\\angry148.png',
#  './datasets/face/original/angry\\angry1480.png',
#  './datasets/face/original/angry\\angry1481.png',
#  './datasets/face/original/angry\\angry1482.png',
#  './datasets/face/original/angry\\angry1483.png',
#  './datasets/face/original/angry\\angry1484.png',
#  './datasets/face/original/angry\\angry1485.png',
#  './datasets/face/original/angry\\angry1486.png',
#  './datasets/face/original/angry\\angry1487.png',
#  './datasets/face/original/angry\\angry1488.png',
#  './datasets/face/original/angry\\angry1489.png',
#  './datasets/face/original/angry\\angry149.png',
#  './datasets/face/original/angry\\angry1490.png',
#  './datasets/face/original/angry\\angry1491.png',
#  './datasets/face/original/angry\\angry1492.png',
#  './datasets/face/original/angry\\angry1493.png',
#  './datasets/face/original/angry\\angry1494.png',
#  './datasets/face/original/angry\\angry1495.png',
#  './datasets/face/original/angry\\angry1496.png',
#  './datasets/face/original/angry\\angry1497.png',
#  './datasets/face/original/angry\\angry1498.png',
#  './datasets/face/original/angry\\angry1499.png',
#  './datasets/face/original/angry\\angry15.png',
#  './datasets/face/original/angry\\angry150.png',
#  './datasets/face/original/angry\\angry1500.png',
#  './datasets/face/original/angry\\angry1501.png',
#  './datasets/face/original/angry\\angry1502.png',
#  './datasets/face/original/angry\\angry1503.png',
#  './datasets/face/original/angry\\angry1504.png',
#  './datasets/face/original/angry\\angry1505.png',
#  './datasets/face/original/angry\\angry1506.png',
#  './datasets/face/original/angry\\angry1507.png',
#  './datasets/face/original/angry\\angry1508.png',
#  './datasets/face/original/angry\\angry1509.png',
#  './datasets/face/original/angry\\angry151.png',
#  './datasets/face/original/angry\\angry1510.png',
#  './datasets/face/original/angry\\angry1511.png',
#  './datasets/face/original/angry\\angry1512.png',
#  './datasets/face/original/angry\\angry1513.png',
#  './datasets/face/original/angry\\angry1514.png',
#  './datasets/face/original/angry\\angry1515.png',
#  './datasets/face/original/angry\\angry1516.png',
#  './datasets/face/original/angry\\angry1517.png',
#  './datasets/face/original/angry\\angry1518.png',
#  './datasets/face/original/angry\\angry1519.png',
#  './datasets/face/original/angry\\angry152.png',
#  './datasets/face/original/angry\\angry1520.png',
#  './datasets/face/original/angry\\angry1521.png',
#  './datasets/face/original/angry\\angry1522.png',
#  './datasets/face/original/angry\\angry1523.png',
#  './datasets/face/original/angry\\angry1524.png',
#  './datasets/face/original/angry\\angry1525.png',
#  './datasets/face/original/angry\\angry1526.png',
#  './datasets/face/original/angry\\angry1527.png',
#  './datasets/face/original/angry\\angry1528.png',
#  './datasets/face/original/angry\\angry1529.png',
#  './datasets/face/original/angry\\angry153.png',
#  './datasets/face/original/angry\\angry1530.png',
#  './datasets/face/original/angry\\angry1531.png',
#  './datasets/face/original/angry\\angry1532.png',
#  './datasets/face/original/angry\\angry1533.png',
#  './datasets/face/original/angry\\angry1534.png',
#  './datasets/face/original/angry\\angry1535.png',
#  './datasets/face/original/angry\\angry1536.png',
#  './datasets/face/original/angry\\angry1537.png',
#  './datasets/face/original/angry\\angry1538.png',
#  './datasets/face/original/angry\\angry1539.png',
#  './datasets/face/original/angry\\angry154.png',
#  './datasets/face/original/angry\\angry1540.png',
#  './datasets/face/original/angry\\angry1541.png',
#  './datasets/face/original/angry\\angry1542.png',
#  './datasets/face/original/angry\\angry1543.png',
#  './datasets/face/original/angry\\angry1544.png',
#  './datasets/face/original/angry\\angry1545.png',
#  './datasets/face/original/angry\\angry1546.png',
#  './datasets/face/original/angry\\angry1547.png',
#  './datasets/face/original/angry\\angry1548.png',
#  './datasets/face/original/angry\\angry1549.png',
#  './datasets/face/original/angry\\angry155.png',
#  './datasets/face/original/angry\\angry1550.png',
#  './datasets/face/original/angry\\angry1551.png',
#  './datasets/face/original/angry\\angry1552.png',
#  './datasets/face/original/angry\\angry1553.png',
#  './datasets/face/original/angry\\angry1554.png',
#  './datasets/face/original/angry\\angry1555.png',
#  './datasets/face/original/angry\\angry1556.png',
#  './datasets/face/original/angry\\angry1557.png',
#  './datasets/face/original/angry\\angry1558.png',
#  './datasets/face/original/angry\\angry1559.png',
#  './datasets/face/original/angry\\angry156.png',
#  './datasets/face/original/angry\\angry1560.png',
#  './datasets/face/original/angry\\angry1561.png',
#  './datasets/face/original/angry\\angry1562.png',
#  './datasets/face/original/angry\\angry1563.png',
#  './datasets/face/original/angry\\angry1564.png',
#  './datasets/face/original/angry\\angry1565.png',
#  './datasets/face/original/angry\\angry1566.png',
#  './datasets/face/original/angry\\angry1567.png',
#  './datasets/face/original/angry\\angry1568.png',
#  './datasets/face/original/angry\\angry1569.png',
#  './datasets/face/original/angry\\angry157.png',
#  './datasets/face/original/angry\\angry1570.png',
#  './datasets/face/original/angry\\angry1571.png',
#  './datasets/face/original/angry\\angry1572.png',
#  './datasets/face/original/angry\\angry1573.png',
#  './datasets/face/original/angry\\angry1574.png',
#  './datasets/face/original/angry\\angry1575.png',
#  './datasets/face/original/angry\\angry1576.png',
#  './datasets/face/original/angry\\angry1577.png',
#  './datasets/face/original/angry\\angry1578.png',
#  './datasets/face/original/angry\\angry1579.png',
#  './datasets/face/original/angry\\angry158.png',
#  './datasets/face/original/angry\\angry1580.png',
#  './datasets/face/original/angry\\angry1581.png',
#  './datasets/face/original/angry\\angry1582.png',
#  './datasets/face/original/angry\\angry1583.png',
#  './datasets/face/original/angry\\angry1584.png',
#  './datasets/face/original/angry\\angry1585.png',
#  './datasets/face/original/angry\\angry1586.png',
#  './datasets/face/original/angry\\angry1587.png',
#  './datasets/face/original/angry\\angry1588.png',
#  './datasets/face/original/angry\\angry1589.png',
#  './datasets/face/original/angry\\angry159.png',
#  './datasets/face/original/angry\\angry1590.png',
#  './datasets/face/original/angry\\angry1591.png',
#  './datasets/face/original/angry\\angry1592.png',
#  './datasets/face/original/angry\\angry1593.png',
#  './datasets/face/original/angry\\angry1594.png',
#  './datasets/face/original/angry\\angry1595.png',
#  './datasets/face/original/angry\\angry1596.png',
#  './datasets/face/original/angry\\angry1597.png',
#  './datasets/face/original/angry\\angry1598.png',
#  './datasets/face/original/angry\\angry1599.png',
#  './datasets/face/original/angry\\angry16.png',
#  './datasets/face/original/angry\\angry160.png',
#  './datasets/face/original/angry\\angry1600.png',
#  './datasets/face/original/angry\\angry1601.png',
#  './datasets/face/original/angry\\angry1602.png',
#  './datasets/face/original/angry\\angry1603.png',
#  './datasets/face/original/angry\\angry1604.png',
#  './datasets/face/original/angry\\angry1605.png',
#  './datasets/face/original/angry\\angry1606.png',
#  './datasets/face/original/angry\\angry1607.png',
#  './datasets/face/original/angry\\angry1608.png',
#  './datasets/face/original/angry\\angry1609.png',
#  './datasets/face/original/angry\\angry161.png',
#  './datasets/face/original/angry\\angry1610.png',
#  './datasets/face/original/angry\\angry1611.png',
#  './datasets/face/original/angry\\angry1612.png',
#  './datasets/face/original/angry\\angry1613.png',
#  './datasets/face/original/angry\\angry1614.png',
#  './datasets/face/original/angry\\angry1615.png',
#  './datasets/face/original/angry\\angry1616.png',
#  './datasets/face/original/angry\\angry1617.png',
#  './datasets/face/original/angry\\angry1618.png',
#  './datasets/face/original/angry\\angry1619.png',
#  './datasets/face/original/angry\\angry162.png',
#  './datasets/face/original/angry\\angry1620.png',
#  './datasets/face/original/angry\\angry1621.png',
#  './datasets/face/original/angry\\angry1622.png',
#  './datasets/face/original/angry\\angry1623.png',
#  './datasets/face/original/angry\\angry1624.png',
#  './datasets/face/original/angry\\angry1625.png',
#  './datasets/face/original/angry\\angry1626.png',
#  './datasets/face/original/angry\\angry1627.png',
#  './datasets/face/original/angry\\angry1628.png',
#  './datasets/face/original/angry\\angry1629.png',
#  './datasets/face/original/angry\\angry163.png',
#  './datasets/face/original/angry\\angry1630.png',
#  './datasets/face/original/angry\\angry1631.png',
#  './datasets/face/original/angry\\angry1632.png',
#  './datasets/face/original/angry\\angry1633.png',
#  './datasets/face/original/angry\\angry1634.png',
#  './datasets/face/original/angry\\angry1635.png',
#  './datasets/face/original/angry\\angry1636.png',
#  './datasets/face/original/angry\\angry1637.png',
#  './datasets/face/original/angry\\angry1638.png',
#  './datasets/face/original/angry\\angry1639.png',
#  './datasets/face/original/angry\\angry164.png',
#  './datasets/face/original/angry\\angry1640.png',
#  './datasets/face/original/angry\\angry1641.png',
#  './datasets/face/original/angry\\angry1642.png',
#  './datasets/face/original/angry\\angry1643.png',
#  './datasets/face/original/angry\\angry1644.png',
#  './datasets/face/original/angry\\angry1645.png',
#  './datasets/face/original/angry\\angry1646.png',
#  './datasets/face/original/angry\\angry1647.png',
#  './datasets/face/original/angry\\angry1648.png',
#  './datasets/face/original/angry\\angry1649.png',
#  './datasets/face/original/angry\\angry165.png',
#  './datasets/face/original/angry\\angry1650.png',
#  './datasets/face/original/angry\\angry1651.png',
#  './datasets/face/original/angry\\angry1652.png',
#  './datasets/face/original/angry\\angry1653.png',
#  './datasets/face/original/angry\\angry1654.png',
#  './datasets/face/original/angry\\angry1655.png',
#  './datasets/face/original/angry\\angry1656.png',
#  './datasets/face/original/angry\\angry1657.png',
#  './datasets/face/original/angry\\angry1658.png',
#  './datasets/face/original/angry\\angry1659.png',
#  './datasets/face/original/angry\\angry166.png',
#  './datasets/face/original/angry\\angry1660.png',
#  './datasets/face/original/angry\\angry1661.png',
#  './datasets/face/original/angry\\angry1662.png',
#  './datasets/face/original/angry\\angry1663.png',
#  './datasets/face/original/angry\\angry1664.png',
#  './datasets/face/original/angry\\angry1665.png',
#  './datasets/face/original/angry\\angry1666.png',
#  './datasets/face/original/angry\\angry1667.png',
#  './datasets/face/original/angry\\angry1668.png',
#  './datasets/face/original/angry\\angry1669.png',
#  './datasets/face/original/angry\\angry167.png',
#  './datasets/face/original/angry\\angry1670.png',
#  './datasets/face/original/angry\\angry1671.png',
#  './datasets/face/original/angry\\angry1672.png',
#  './datasets/face/original/angry\\angry1673.png',
#  './datasets/face/original/angry\\angry1674.png',
#  './datasets/face/original/angry\\angry1675.png',
#  './datasets/face/original/angry\\angry1676.png',
#  './datasets/face/original/angry\\angry1677.png',
#  './datasets/face/original/angry\\angry1678.png',
#  './datasets/face/original/angry\\angry1679.png',
#  './datasets/face/original/angry\\angry168.png',
#  './datasets/face/original/angry\\angry1680.png',
#  './datasets/face/original/angry\\angry1681.png',
#  './datasets/face/original/angry\\angry1682.png',
#  './datasets/face/original/angry\\angry1683.png',
#  './datasets/face/original/angry\\angry1684.png',
#  './datasets/face/original/angry\\angry1685.png',
#  './datasets/face/original/angry\\angry1686.png',
#  './datasets/face/original/angry\\angry1687.png',
#  './datasets/face/original/angry\\angry1688.png',
#  './datasets/face/original/angry\\angry1689.png',
#  './datasets/face/original/angry\\angry169.png',
#  './datasets/face/original/angry\\angry1690.png',
#  './datasets/face/original/angry\\angry1691.png',
#  './datasets/face/original/angry\\angry1692.png',
#  './datasets/face/original/angry\\angry1693.png',
#  './datasets/face/original/angry\\angry1694.png',
#  './datasets/face/original/angry\\angry1695.png',
#  './datasets/face/original/angry\\angry1696.png',
#  './datasets/face/original/angry\\angry1697.png',
#  './datasets/face/original/angry\\angry1698.png',
#  './datasets/face/original/angry\\angry1699.png',
#  './datasets/face/original/angry\\angry17.png',
#  './datasets/face/original/angry\\angry170.png',
#  './datasets/face/original/angry\\angry1700.png',
#  './datasets/face/original/angry\\angry1701.png',
#  './datasets/face/original/angry\\angry1702.png',
#  './datasets/face/original/angry\\angry1703.png',
#  './datasets/face/original/angry\\angry1704.png',
#  './datasets/face/original/angry\\angry1705.png',
#  './datasets/face/original/angry\\angry1706.png',
#  './datasets/face/original/angry\\angry1707.png',
#  './datasets/face/original/angry\\angry1708.png',
#  './datasets/face/original/angry\\angry1709.png',
#  './datasets/face/original/angry\\angry171.png',
#  './datasets/face/original/angry\\angry1710.png',
#  './datasets/face/original/angry\\angry1711.png',
#  './datasets/face/original/angry\\angry1712.png',
#  './datasets/face/original/angry\\angry1713.png',
#  './datasets/face/original/angry\\angry1714.png',
#  './datasets/face/original/angry\\angry1715.png',
#  './datasets/face/original/angry\\angry1716.png',
#  './datasets/face/original/angry\\angry1717.png',
#  './datasets/face/original/angry\\angry1718.png',
#  './datasets/face/original/angry\\angry1719.png',
#  './datasets/face/original/angry\\angry172.png',
#  './datasets/face/original/angry\\angry1720.png',
#  './datasets/face/original/angry\\angry1721.png',
#  './datasets/face/original/angry\\angry1722.png',
#  './datasets/face/original/angry\\angry1723.png',
#  './datasets/face/original/angry\\angry1724.png',
#  './datasets/face/original/angry\\angry1725.png',
#  './datasets/face/original/angry\\angry1726.png',
#  './datasets/face/original/angry\\angry1727.png',
#  './datasets/face/original/angry\\angry1728.png',
#  './datasets/face/original/angry\\angry1729.png',
#  './datasets/face/original/angry\\angry173.png',
#  './datasets/face/original/angry\\angry1730.png',
#  './datasets/face/original/angry\\angry1731.png',
#  './datasets/face/original/angry\\angry1732.png',
#  './datasets/face/original/angry\\angry1733.png',
#  './datasets/face/original/angry\\angry1734.png',
#  './datasets/face/original/angry\\angry1735.png',
#  './datasets/face/original/angry\\angry1736.png',
#  './datasets/face/original/angry\\angry1737.png',
#  './datasets/face/original/angry\\angry1738.png',
#  './datasets/face/original/angry\\angry1739.png',
#  './datasets/face/original/angry\\angry174.png',
#  './datasets/face/original/angry\\angry1740.png',
#  './datasets/face/original/angry\\angry1741.png',
#  './datasets/face/original/angry\\angry1742.png',
#  './datasets/face/original/angry\\angry1743.png',
#  './datasets/face/original/angry\\angry1744.png',
#  './datasets/face/original/angry\\angry1745.png',
#  './datasets/face/original/angry\\angry1746.png',
#  './datasets/face/original/angry\\angry1747.png',
#  './datasets/face/original/angry\\angry1748.png',
#  './datasets/face/original/angry\\angry1749.png',
#  './datasets/face/original/angry\\angry175.png',
#  './datasets/face/original/angry\\angry1750.png',
#  './datasets/face/original/angry\\angry1751.png',
#  './datasets/face/original/angry\\angry1752.png',
#  './datasets/face/original/angry\\angry1753.png',
#  './datasets/face/original/angry\\angry1754.png',
#  './datasets/face/original/angry\\angry1755.png',
#  './datasets/face/original/angry\\angry1756.png',
#  './datasets/face/original/angry\\angry1757.png',
#  './datasets/face/original/angry\\angry1758.png',
#  './datasets/face/original/angry\\angry1759.png',
#  './datasets/face/original/angry\\angry176.png',
#  './datasets/face/original/angry\\angry1760.png',
#  './datasets/face/original/angry\\angry1761.png',
#  './datasets/face/original/angry\\angry1762.png',
#  './datasets/face/original/angry\\angry1763.png',
#  './datasets/face/original/angry\\angry1764.png',
#  './datasets/face/original/angry\\angry1765.png',
#  './datasets/face/original/angry\\angry1766.png',
#  './datasets/face/original/angry\\angry1767.png',
#  './datasets/face/original/angry\\angry1768.png',
#  './datasets/face/original/angry\\angry1769.png',
#  './datasets/face/original/angry\\angry177.png',
#  './datasets/face/original/angry\\angry1770.png',
#  './datasets/face/original/angry\\angry1771.png',
#  './datasets/face/original/angry\\angry1772.png',
#  './datasets/face/original/angry\\angry1773.png',
#  './datasets/face/original/angry\\angry1774.png',
#  './datasets/face/original/angry\\angry1775.png',
#  './datasets/face/original/angry\\angry1776.png',
#  './datasets/face/original/angry\\angry1777.png',
#  './datasets/face/original/angry\\angry1778.png',
#  './datasets/face/original/angry\\angry1779.png',
#  './datasets/face/original/angry\\angry178.png',
#  './datasets/face/original/angry\\angry1780.png',
#  './datasets/face/original/angry\\angry1781.png',
#  './datasets/face/original/angry\\angry1782.png',
#  './datasets/face/original/angry\\angry1783.png',
#  './datasets/face/original/angry\\angry1784.png',
#  './datasets/face/original/angry\\angry1785.png',
#  './datasets/face/original/angry\\angry1786.png',
#  './datasets/face/original/angry\\angry1787.png',
#  './datasets/face/original/angry\\angry1788.png',
#  './datasets/face/original/angry\\angry1789.png',
#  './datasets/face/original/angry\\angry179.png',
#  './datasets/face/original/angry\\angry1790.png',
#  './datasets/face/original/angry\\angry1791.png',
#  './datasets/face/original/angry\\angry1792.png',
#  './datasets/face/original/angry\\angry1793.png',
#  './datasets/face/original/angry\\angry1794.png',
#  './datasets/face/original/angry\\angry1795.png',
#  './datasets/face/original/angry\\angry1796.png',
#  './datasets/face/original/angry\\angry1797.png',
#  './datasets/face/original/angry\\angry1798.png',
#  './datasets/face/original/angry\\angry1799.png',
#  './datasets/face/original/angry\\angry18.png',
#  './datasets/face/original/angry\\angry180.png',
#  './datasets/face/original/angry\\angry1800.png',
#  './datasets/face/original/angry\\angry1801.png',
#  './datasets/face/original/angry\\angry1802.png',
#  './datasets/face/original/angry\\angry1803.png',
#  './datasets/face/original/angry\\angry1804.png',
#  './datasets/face/original/angry\\angry1805.png',
#  './datasets/face/original/angry\\angry1806.png',
#  './datasets/face/original/angry\\angry1807.png',
#  './datasets/face/original/angry\\angry1808.png',
#  './datasets/face/original/angry\\angry1809.png',
#  './datasets/face/original/angry\\angry181.png',
#  './datasets/face/original/angry\\angry1810.png',
#  './datasets/face/original/angry\\angry1811.png',
#  './datasets/face/original/angry\\angry1812.png',
#  './datasets/face/original/angry\\angry1813.png',
#  './datasets/face/original/angry\\angry1814.png',
#  './datasets/face/original/angry\\angry1815.png',
#  './datasets/face/original/angry\\angry1816.png',
#  './datasets/face/original/angry\\angry1817.png',
#  './datasets/face/original/angry\\angry1818.png',
#  './datasets/face/original/angry\\angry1819.png',
#  './datasets/face/original/angry\\angry182.png',
#  './datasets/face/original/angry\\angry1820.png',
#  './datasets/face/original/angry\\angry1821.png',
#  './datasets/face/original/angry\\angry1822.png',
#  './datasets/face/original/angry\\angry1823.png',
#  './datasets/face/original/angry\\angry1824.png',
#  './datasets/face/original/angry\\angry1825.png',
#  './datasets/face/original/angry\\angry1826.png',
#  './datasets/face/original/angry\\angry1827.png',
#  './datasets/face/original/angry\\angry1828.png',
#  './datasets/face/original/angry\\angry1829.png',
#  './datasets/face/original/angry\\angry183.png',
#  './datasets/face/original/angry\\angry1830.png',
#  './datasets/face/original/angry\\angry1831.png',
#  './datasets/face/original/angry\\angry1832.png',
#  './datasets/face/original/angry\\angry1833.png',
#  './datasets/face/original/angry\\angry1834.png',
#  './datasets/face/original/angry\\angry1835.png',
#  './datasets/face/original/angry\\angry1836.png',
#  './datasets/face/original/angry\\angry1837.png',
#  './datasets/face/original/angry\\angry1838.png',
#  './datasets/face/original/angry\\angry1839.png',
#  './datasets/face/original/angry\\angry184.png',
#  './datasets/face/original/angry\\angry1840.png',
#  './datasets/face/original/angry\\angry1841.png',
#  './datasets/face/original/angry\\angry1842.png',
#  './datasets/face/original/angry\\angry1843.png',
#  './datasets/face/original/angry\\angry1844.png',
#  './datasets/face/original/angry\\angry1845.png',
#  './datasets/face/original/angry\\angry1846.png',
#  './datasets/face/original/angry\\angry1847.png',
#  './datasets/face/original/angry\\angry1848.png',
#  './datasets/face/original/angry\\angry1849.png',
#  './datasets/face/original/angry\\angry185.png',
#  './datasets/face/original/angry\\angry1850.png',
#  './datasets/face/original/angry\\angry1851.png',
#  './datasets/face/original/angry\\angry1852.png',
#  './datasets/face/original/angry\\angry1853.png',
#  './datasets/face/original/angry\\angry1854.png',
#  './datasets/face/original/angry\\angry1855.png',
#  './datasets/face/original/angry\\angry1856.png',
#  './datasets/face/original/angry\\angry1857.png',
#  './datasets/face/original/angry\\angry1858.png',
#  './datasets/face/original/angry\\angry1859.png',
#  './datasets/face/original/angry\\angry186.png',
#  './datasets/face/original/angry\\angry1860.png',
#  './datasets/face/original/angry\\angry1861.png',
#  './datasets/face/original/angry\\angry1862.png',
#  './datasets/face/original/angry\\angry1863.png',
#  './datasets/face/original/angry\\angry1864.png',
#  './datasets/face/original/angry\\angry1865.png',
#  './datasets/face/original/angry\\angry1866.png',
#  './datasets/face/original/angry\\angry1867.png',
#  './datasets/face/original/angry\\angry1868.png',
#  './datasets/face/original/angry\\angry1869.png',
#  './datasets/face/original/angry\\angry187.png',
#  './datasets/face/original/angry\\angry1870.png',
#  './datasets/face/original/angry\\angry1871.png',
#  './datasets/face/original/angry\\angry1872.png',
#  './datasets/face/original/angry\\angry1873.png',
#  './datasets/face/original/angry\\angry1874.png',
#  './datasets/face/original/angry\\angry1875.png',
#  './datasets/face/original/angry\\angry1876.png',
#  './datasets/face/original/angry\\angry1877.png',
#  './datasets/face/original/angry\\angry1878.png',
#  './datasets/face/original/angry\\angry1879.png',
#  './datasets/face/original/angry\\angry188.png',
#  './datasets/face/original/angry\\angry1880.png',
#  './datasets/face/original/angry\\angry1881.png',
#  './datasets/face/original/angry\\angry1882.png',
#  './datasets/face/original/angry\\angry1883.png',
#  './datasets/face/original/angry\\angry1884.png',
#  './datasets/face/original/angry\\angry1885.png',
#  './datasets/face/original/angry\\angry1886.png',
#  './datasets/face/original/angry\\angry1887.png',
#  './datasets/face/original/angry\\angry1888.png',
#  './datasets/face/original/angry\\angry1889.png',
#  './datasets/face/original/angry\\angry189.png',
#  './datasets/face/original/angry\\angry1890.png',
#  './datasets/face/original/angry\\angry1891.png',
#  './datasets/face/original/angry\\angry1892.png',
#  './datasets/face/original/angry\\angry1893.png',
#  './datasets/face/original/angry\\angry1894.png',
#  './datasets/face/original/angry\\angry1895.png',
#  './datasets/face/original/angry\\angry1896.png',
#  './datasets/face/original/angry\\angry1897.png',
#  './datasets/face/original/angry\\angry1898.png',
#  './datasets/face/original/angry\\angry1899.png',
#  ...]

# %%
import pandas as pd

# 파일 경로와 타겟값을 가지고 새로운 데이터 프레임 생성
train_df = pd.DataFrame({'file_paths': generator.filepaths, 'targets': generator.classes})
train_df
# Out:
#                                               file_paths  targets
# 0              ./datasets/face/original/angry\angry1.png        0
# 1             ./datasets/face/original/angry\angry10.png        0
# 2            ./datasets/face/original/angry\angry100.png        0
# 3           ./datasets/face/original/angry\angry1000.png        0
# 4           ./datasets/face/original/angry\angry1001.png        0
# ...                                                  ...      ...
# 28704  ./datasets/face/original/surprise\surprise995.png        6
# 28705  ./datasets/face/original/surprise\surprise996.png        6
# 28706  ./datasets/face/original/surprise\surprise997.png        6
# 28707  ./datasets/face/original/surprise\surprise998.png        6
# 28708  ./datasets/face/original/surprise\surprise999.png        6
#
# [28709 rows x 2 columns]

# %%
# 경로 중 \\(역슬래시)로 되어 있는 부분을 /(슬래시)로 변경
train_df.loc[:, 'file_paths'] = train_df.file_paths.apply(lambda x: x.replace('\\', '/'))
train_df
# Out:
#                                               file_paths  targets
# 0              ./datasets/face/original/angry/angry1.png        0
# 1             ./datasets/face/original/angry/angry10.png        0
# 2            ./datasets/face/original/angry/angry100.png        0
# 3           ./datasets/face/original/angry/angry1000.png        0
# 4           ./datasets/face/original/angry/angry1001.png        0
# ...                                                  ...      ...
# 28704  ./datasets/face/original/surprise/surprise995.png        6
# 28705  ./datasets/face/original/surprise/surprise996.png        6
# 28706  ./datasets/face/original/surprise/surprise997.png        6
# 28707  ./datasets/face/original/surprise/surprise998.png        6
# 28708  ./datasets/face/original/surprise/surprise999.png        6
#
# [28709 rows x 2 columns]

# %% [markdown]
# #### test

# %%
from glob import glob
import os

# 이미지가 저장되어 있는 경로 지정
root = './datasets/face/test/'

# 해당 경로를 통해 이미지 폴더를 찾아옴
directories = glob(os.path.join(root, '*'))

# %%
# 폴더 이름 저장할 초기 list 생성
directory_names = []

for directory in directories:
    # 디렉토리의 이름을 찾아와서 list에 저장
    directory_names.append(directory[directory.rindex('\\') + 1:])

print(directory_names)
# Out:
# ['angry', 'disgust', 'fear', 'happy', 'neutral', 'sad', 'surprise']

# %%
# 이미지 별 폴더 안 이미지들의 파일명 변경
for name in directory_names:
    for i, file_name in enumerate(os.listdir(os.path.join(root, name))):
        # 이전 파일의 전체 경로
        old_file = os.path.join(root + name + '/', file_name)
        # 신규 파일 전체 경로 작성
        new_file = os.path.join(root + name + '/', name + str(i + 1) + '.png')

        os.rename(old_file, new_file)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 이미지의 픽셀 값을 0에서 255 사이에서 0에서 1 사이의 값으로 조정
image_data_generator = ImageDataGenerator(rescale=1./255)

# 디렉토리에서 이미지를 가져와 배치로 변환
generator = image_data_generator.flow_from_directory(root, target_size=(150, 150), batch_size=32, class_mode='categorical')

print(generator.class_indices)
# Out:
# Found 7178 images belonging to 7 classes.
# {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}

# %%
import pandas as pd

# 파일 경로와 타겟값을 가지고 새로운 데이터 프레임 생성
test_df = pd.DataFrame({'file_paths': generator.filepaths, 'targets': generator.classes})
test_df
# Out:
#                                         file_paths  targets
# 0            ./datasets/face/test/angry\angry1.png        0
# 1           ./datasets/face/test/angry\angry10.png        0
# 2          ./datasets/face/test/angry\angry100.png        0
# 3          ./datasets/face/test/angry\angry101.png        0
# 4          ./datasets/face/test/angry\angry102.png        0
# ...                                            ...      ...
# 7173  ./datasets/face/test/surprise\surprise95.png        6
# 7174  ./datasets/face/test/surprise\surprise96.png        6
# 7175  ./datasets/face/test/surprise\surprise97.png        6
# 7176  ./datasets/face/test/surprise\surprise98.png        6
# 7177  ./datasets/face/test/surprise\surprise99.png        6
#
# [7178 rows x 2 columns]

# %%
# 경로 중 \\(역슬래시)로 되어 있는 부분을 /(슬래시)로 변경
test_df.loc[:, 'file_paths'] = test_df.file_paths.apply(lambda x: x.replace('\\', '/'))
test_df
# Out:
#                                         file_paths  targets
# 0            ./datasets/face/test/angry/angry1.png        0
# 1           ./datasets/face/test/angry/angry10.png        0
# 2          ./datasets/face/test/angry/angry100.png        0
# 3          ./datasets/face/test/angry/angry101.png        0
# 4          ./datasets/face/test/angry/angry102.png        0
# ...                                            ...      ...
# 7173  ./datasets/face/test/surprise/surprise95.png        6
# 7174  ./datasets/face/test/surprise/surprise96.png        6
# 7175  ./datasets/face/test/surprise/surprise97.png        6
# 7176  ./datasets/face/test/surprise/surprise98.png        6
# 7177  ./datasets/face/test/surprise/surprise99.png        6
#
# [7178 rows x 2 columns]

# %% [markdown]
# #### 데이터 세트 분리

# %%
from sklearn.model_selection import train_test_split

# 학습 및 검증용 데이터 세트 분리
X_train, X_val, y_train, y_val = \
train_test_split(train_df.file_paths, train_df.targets, stratify=train_df.targets, test_size=0.2, random_state=124)

print(y_train.value_counts())
print(y_val.value_counts())
# Out:
# targets
# 3    5772
# 4    3972
# 5    3864
# 2    3277
# 0    3196
# 6    2537
# 1     349
# Name: count, dtype: int64
# targets
# 3    1443
# 4     993
# 5     966
# 2     820
# 0     799
# 6     634
# 1      87
# Name: count, dtype: int64

# %%
# 테스트 데이터 세트 분리
X_test = test_df.file_paths
y_test = test_df.targets

print(y_test.value_counts())
# Out:
# targets
# 3    1774
# 5    1247
# 4    1233
# 2    1024
# 0     958
# 6     831
# 1     111
# Name: count, dtype: int64

# %%
import shutil

# 경로 지정
root = './datasets/face/'

for file_path in X_train:
    # 이미지 파일의 원본 디렉터리 경로 저장
    face_dir = file_path[len(root + 'original/'): file_path.rindex('/')]
    # 이미지 파일을 복사할 훈련용 디렉터리의 경로 저장
    destination = os.path.join(root, 'train/' + face_dir)

    # 훈련용 디렉터리가 없는 경우 해당 디렉터리를 생성
    if not os.path.exists(destination):
        os.makedirs(destination)

    # 이미지 파일을 훈련용 디렉터리로 복사
    shutil.copy2(file_path, destination)

# %%
import shutil

# 경로 지정
root = './datasets/face/'

for file_path in X_val:
    # 이미지 파일의 원본 디렉터리 경로 저장
    face_dir = file_path[len(root + 'original/'): file_path.rindex('/')]
    # 이미지 파일을 복사할 훈련용 디렉터리의 경로 저장
    destination = os.path.join(root, 'validation/' + face_dir)

    # 훈련용 디렉터리가 없는 경우 해당 디렉터리를 생성
    if not os.path.exists(destination):
        os.makedirs(destination)

    # 이미지 파일을 훈련용 디렉터리로 복사
    shutil.copy2(file_path, destination)
